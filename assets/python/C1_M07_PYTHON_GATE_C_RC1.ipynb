# %% [markdown]
# # Course 1 — M07 Python Gate C — Subscription Retention — RC1
#
# **Protected independent assessment.** Learner book, practice review, Gate review, solved notebooks/tutorials and AI-generated solutions are closed for the genuine attempt.
#
# **Business request:** Growth says cancellations may be concentrated by plan, region or channel. Quantify the pattern, validate plan enrichment and identify revenue at risk without overstating causation.
#
# **Files**
# - `Gate_Data/Gate_C/subscriptions.csv`
# - `Gate_Data/Gate_C/plans.csv`
#
# **State:** Gate C is remediation-only after failed B + repair + explicit assignment. Clean C pass ends M07. There is no Gate D.

# %%
from pathlib import Path
import sys
import pandas as pd
import matplotlib.pyplot as plt

print("Python:", sys.version.split()[0])
print("Working folder:", Path.cwd())
OUTPUT = Path("gate_outputs")
OUTPUT.mkdir(exist_ok=True)

# %% [markdown]
# ## Required competency evidence
#
# 1. Frame the business question and metric definitions before analysis.
# 2. Load and inspect every supplied file; preserve raw frames.
# 3. Detect duplicates, missing/invalid values and date/numeric problems **before** correction.
# 4. Create cleaned/prepared copies and document every dropped/rejected row.
# 5. Prove dimension-key uniqueness before enrichment.
# 6. Merge with `validate=` and `indicator=True`; count unmatched keys.
# 7. State source grain and each grouped/result grain.
# 8. Use dates, groupby/aggregation and reshaping only where useful.
# 9. Create 2–3 separate purposeful Matplotlib/pandas figures.
# 10. Reconcile at least one important count/rate/total independently.
# 11. Write three supported findings, one recommendation and limitations; do not turn association into causation.
# 12. Save output(s), Restart Kernel → Run All, and save one error/recovery note.
#
# **Critical failures can block a pass:** hidden/deleted evidence, duplicate-key merge risk ignored, unmatched rows hidden, wrong denominator/rate, invalid dates included as valid, refund/revenue multiplication, no reconciliation, notebook hidden state, or inability to explain the result.

# %%
# Gate C independent analysis starts here.

# %% [markdown]
# ## Validation / evidence before review
#
# Save:
# - raw and prepared row counts,
# - duplicate/invalid/rejected counts,
# - dimension-key uniqueness result,
# - `_merge` counts / unmatched keys,
# - exact metric definitions,
# - one independent reconciliation,
# - output figure/table paths,
# - findings/recommendation/limitations,
# - Restart + Run All result,
# - confidence 1–5.
#
# **Only after this is saved may you open the protected Gate review.**

# %%
# Gate C validation/evidence checks here.

# %% [markdown]
# ## Exact next route
#
# Gate C is remediation-only after failed B + repair + explicit assignment. Clean C pass ends M07. There is no Gate D.
#
# If repair is needed, preserve this attempt, open the Gate C protected review, repair only the named weak competency, **close the review**, complete changed evidence, and only then follow the state machine.
