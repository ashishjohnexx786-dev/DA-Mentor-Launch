# %% [markdown]
# # Course 1 — M07 Python for Data Analysts — Canonical Practice Notebook RC1
#
# **This notebook is practice. The learner book is the teacher.**
#
# Route for every lesson: **learn → mapped visual if useful → teacher demo → guided attempt → changed independent attempt → validate → explain back → append evidence**.
#
# Protected review stays closed until a genuine saved attempt exists. Do not erase failed attempts.
# At the end, use **Restart Kernel → Run All** to detect hidden state.

# %%
from pathlib import Path
import sys
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

BASE = Path("Practice_Data")
OUTPUT = Path("outputs")
OUTPUT.mkdir(exist_ok=True)

print("Python:", sys.version.split()[0])
print("Executable:", sys.executable)
print("Working folder:", Path.cwd())
print("pandas:", pd.__version__)
print("matplotlib:", matplotlib.__version__)
print("Practice data exists:", BASE.exists())

# %% [markdown]
# ## Source files and preservation rule
#
# - `Practice_Data/sales.csv` — transaction-line source; preserve raw.
# - `Practice_Data/products.csv` — product dimension.
# - `Practice_Data/customers.csv` — customer dimension with a deliberate key-quality trap.
# - `Practice_Data/returns.csv` — order-level returns/refunds.
# - `Practice_Data/region_targets.json` — small target reference.
#
# Never overwrite the source files. Create new DataFrames/outputs.

# %% [markdown]
# ## PY0 — Python, Jupyter and a reproducible analyst notebook
#
# **Open learner book:** `PY0` section before coding.
# **Outcome:** - Understand the notebook/code/output mental model. - Install a stable environment and verify it. - Run cells in order and restart/run-all before delivery.
#
# ### Guided attempt
# 1. Print `sys.executable`, Python/pandas/Matplotlib versions and `Path.cwd()`.
# 2. Verify every Practice_Data file exists.
# 3. Restart the kernel and Run All.
# 4. Write one sentence explaining hidden state.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY0 guided attempt
# Environment setup is in the notebook setup cell above.

# %% [markdown]
# ### Changed independent attempt
# Change `OUTPUT` to a new folder such as `outputs_retry`, restart the kernel, Run All, and prove the notebook recreates what it needs without relying on a forgotten cell.
#
# **Explain back:** A notebook mixes explanation and executable code. That is useful for analysis because another person can see not only the result, but how you obtained it. A reproducible notebook should run from the first cell to the last without depending on hidden state. A cell that works only because you ran some forgotten cell earlier is not a reliable analysis.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY0 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# ## PY1 — Practical Python basics: values, conditions, loops and functions
#
# **Open learner book:** `PY1` section before coding.
# **Outcome:** - Use variables and common data types. - Write simple conditions and loops without overengineering. - Create small reusable functions for analyst rules.
#
# ### Guided attempt
# Create `revenue`, `cost`, `orders`; calculate profit and average order value. Write a `sales_band(net_sales)` function using High >= 100000, Medium >= 50000, otherwise Low. Test 49,999 / 50,000 / 99,999 / 100,000. Then apply the function to six values with a `for` loop.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY1 guided attempt
# Write your variables, condition/function, boundary tests and loop here.

# %% [markdown]
# ### Changed independent attempt
# Create a different business function, e.g. `delivery_band(hours)`, with at least two exact thresholds. Test just-below / exactly-at / just-above boundaries, then process a list with a loop.
#
# **Explain back:** Python fundamentals matter only because they let you express business logic. A variable gives a value a name. A condition chooses between outcomes. A loop repeats a small operation. A function packages a rule so you can reuse and test it. For analyst work, clarity is more important than clever code.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY1 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# ## PY2 — pandas: load, inspect, select and filter
#
# **Open learner book:** `PY2` section before coding.
# **Outcome:** - Load CSV/Excel/JSON data. - Inspect shape, columns, types, missingness and samples. - Select columns and filter rows using explicit conditions.
#
# ### Guided attempt
# Load `sales.csv` into `sales_raw`. Show `head()`, `shape`, column names, dtypes, `info()`, missing counts and duplicate `order_line_id` evidence. Then select explicit columns and filter a clearly stated business scope using `.loc[]`.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY2 guided attempt
# Example start: sales_raw = pd.read_csv(BASE / "sales.csv")

# %% [markdown]
# ### Changed independent attempt
# Load a different supplied file. Report shape/types/missing/key uniqueness. Filter two conditions and write what one returned row represents and which rows are in scope.
#
# **Explain back:** A pandas DataFrame is a table-like object. Before analysis, inspect the dataset rather than assuming its shape or data types. Useful first checks: head(), shape, columns, dtypes, info(), missing counts and key uniqueness. Filtering changes which rows are in scope, so filters must reflect the business question.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY2 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# ## PY3 — Data quality and cleaning in pandas
#
# **Open learner book:** `PY3` section before coding.
# **Outcome:** - Separate detection from correction. - Clean text and dates transparently. - Treat duplicates, missing data and invalid values using business rules.
#
# ### Guided attempt
# Work from `sales_raw.copy()`. Detect before correcting: whitespace/case in region, duplicate `order_line_id`, invalid discount outside 0–1, invalid `order_date` / `actual_date`, and missing values. Use transparent helper/parsed fields. Keep an issue log and before/after row counts.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY3 guided attempt
# Start from a copy, never overwrite sales_raw.
# work = sales_raw.copy()

# %% [markdown]
# ### Changed independent attempt
# Create a small dirty DataFrame yourself with whitespace, one invalid date, one duplicate key and one invalid numeric value. Detect every issue first; then apply only justified corrections and prove what changed.
#
# **Explain back:** Cleaning is not 'make warnings disappear.' Preserve evidence, identify the rule, investigate impact and document the decision. Use .str.strip() for whitespace, pd.to_datetime(..., errors='coerce') when you want invalid date text to become visible as missing, duplicated() for duplicate detection, and explicit range/rule checks for invalid values.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY3 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# ## PY4 — GroupBy, aggregation and result grain
#
# **Open learner book:** `PY4` section before coding.
# **Outcome:** - Aggregate measures by meaningful business dimensions. - Use named aggregation for readable outputs. - State what one result row represents.
#
# ### Guided attempt
# On a justified analysis set, create `net_sales`. Build a named aggregation by `region` with row count, distinct orders, net sales and one average. State result grain and reconcile grouped `net_sales` to the source analysis-set total.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY4 guided attempt
# Build a justified analysis set first, then named groupby aggregation.

# %% [markdown]
# ### Changed independent attempt
# Group by a different dimension or two-dimension combination. Include rows, distinct entities, sum and mean; state exact result grain and reconcile the additive metric.
#
# **Explain back:** groupby changes grain. If you group by region, one output row represents one region. If you group by month and category, each output row represents one month-category combination. Always check whether a metric is additive at that grain. Counts, distinct counts and averages answer different questions.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY4 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# ## PY5 — Merge, concat and validation
#
# **Open learner book:** `PY5` section before coding.
# **Outcome:** - Choose join keys intentionally. - Detect one-to-many risks before merging. - Validate row counts and unmatched keys after merge.
#
# ### Guided attempt
# Load products/customers. Clean join keys without overwriting raw. Prove product key uniqueness, then merge product attributes with `validate="many_to_one"` and `indicator=True`; count unmatched rows. Demonstrate that the cleaned customer key fails the intended uniqueness rule before any repair.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY5 guided attempt
# Load dimensions; prove key uniqueness before merge(validate=..., indicator=True).

# %% [markdown]
# ### Changed independent attempt
# Build a small fact/dimension pair with one unmatched key. Prove dimension uniqueness, merge with `validate=` and `indicator=True`, and explain the `_merge` counts. Then deliberately create a duplicate dimension key and show the validation failure.
#
# **Explain back:** A merge is the Python equivalent of a relational join. It can silently multiply rows if the right-side key is not unique. Before a many-to-one enrichment merge, test the dimension key for duplicates. During merge, `validate='many_to_one'` makes pandas raise an error if the assumed relationship is false. `indicator=True` exposes unmatched rows.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY5 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# ## PY6 — Reshape and time analysis
#
# **Open learner book:** `PY6` section before coding.
# **Outcome:** - Parse dates and create time attributes. - Pivot long data to a reporting matrix. - Return wide summaries to long/tidy form when useful.
#
# ### Guided attempt
# Parse the analysis date, create month, group month + region net sales, pivot to a reporting matrix, then return the matrix to tidy/long form with `melt`. Reconcile row meaning and total before/after reshape.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY6 guided attempt
# Parse dates -> month summary -> pivot wide -> melt long -> reconcile.

# %% [markdown]
# ### Changed independent attempt
# Use a changed dimension with month, build long → wide → long, sort chronologically, and prove the additive total is unchanged.
#
# **Explain back:** Analyst data often moves between long and wide forms. Long form is usually easier for filtering, grouping and plotting. A pivot table is useful for a matrix view such as Month x Region. Time analysis begins with real datetime values, not strings that merely look like dates.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY6 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# ## PY7 — Visualization with pandas and Matplotlib
#
# **Open learner book:** `PY7` section before coding.
# **Outcome:** - Choose charts based on analytical question. - Create readable line/bar/histogram plots. - Label axes/titles and avoid decorative complexity.
#
# ### Guided attempt
# From validated summarized data, create three separate figures: one monthly line trend, one region/category bar comparison and one numeric histogram. Add meaningful title/x/y labels and save each figure under `outputs/`.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY7 guided attempt
# Create each chart as a separate figure; validate summarized data before formatting.

# %% [markdown]
# ### Changed independent attempt
# Create one time trend and one category comparison on a changed slice. Explain why each chart type matches the question. Do not add 3D/decorative clutter.
#
# **Explain back:** Use a line chart for ordered time trends, a bar chart for category comparison and a histogram/boxplot for distribution questions. A chart is part of the argument, not decoration. The goal is not to memorize every Matplotlib option. Create a clear first chart, then improve labels and formatting only as needed.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY7 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# ## PY8 — Exploratory data analysis (EDA)
#
# **Open learner book:** `PY8` section before coding.
# **Outcome:** - Perform a structured first-pass analysis. - Separate suspicious data from business findings. - Use grouped analysis and visuals to form evidence-based observations.
#
# ### Guided attempt
# Run a compact EDA: shape/types/missing/duplicate/key checks, descriptive statistics, useful category counts, grouped metrics, time trend, suspicious values, 2–3 purposeful visuals, three observations and limitations. Separate data-quality findings from business findings.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY8 guided attempt
# Structure -> quality -> distribution -> groups -> trend -> findings -> limitations.

# %% [markdown]
# ### Changed independent attempt
# Choose a changed scope (for example one quarter or segment) and repeat a compact EDA. Keep only checks/visuals that answer structure, quality, distribution, comparison or trend questions.
#
# **Explain back:** EDA is not 'make every chart.' Start with structure and quality, then examine distributions, categories, trends, grouped metrics and unusual values that matter to the question. An observation becomes useful when you connect it to context: what changed, where, how much, compared with what, and what limitation remains.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY8 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# ## PY9 — Notebook quality, outputs and reproducibility
#
# **Open learner book:** `PY9` section before coding.
# **Outcome:** - Organize a notebook so another analyst can follow it. - Save important outputs intentionally. - Run top-to-bottom and avoid hidden state.
#
# ### Guided attempt
# Reorganize your work into: question → imports/setup → load → quality audit → preparation → merge → analysis → validation → visuals → findings/limitations → outputs. Save one analysis table to CSV with `index=False`. Restart Kernel → Run All.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY9 guided attempt
# Reorganize your notebook, save outputs, then Restart Kernel -> Run All.

# %% [markdown]
# ### Changed independent attempt
# Copy your notebook, intentionally move/remove one dependency, observe the clean-run failure, then repair the earliest failing cell and prove a full Run All succeeds.
#
# **Explain back:** A professional notebook should have a visible question, imports/setup, loading, quality checks, preparation, analysis, validation, visuals, findings and limitations. Do not scatter unexplained code across random cells. Avoid writing over raw data. Save clean outputs with clear filenames. Before delivery: Restart Kernel -> Run All -> confirm no error.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY9 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# ## PY10 — Integrated analyst workflow in Python
#
# **Open learner book:** `PY10` section before coding.
# **Outcome:** - Combine framing, quality, cleaning, merging, analysis and communication. - Choose the smallest useful set of techniques. - Defend your result with validation evidence.
#
# ### Guided attempt
# Use the course files to complete one compact analyst workflow: frame the question, audit data, prepare, validate merges, analyze/group/reshape, visualize, reconcile, communicate and rerun. Use only techniques needed for the question.
#
# **Validation:** Save shape/key/type/count/total evidence appropriate to the lesson. A cell running without an error is not by itself validation.

# %%
# PY10 guided attempt
# Build only the smallest useful end-to-end workflow for the business question.

# %% [markdown]
# ### Changed independent attempt
# Start from only a fresh business request and the supplied files. Build an end-to-end mini-case without reopening the lesson/review: frame → audit → prepare → merge → analyze → visualize → validate → communicate → Restart + Run All.
#
# **Explain back:** The final Python skill is not a new function. It is integration. You receive an unfamiliar request and unfamiliar data, then decide what to check, what to calculate, how to validate and how to communicate. Your notebook is evidence of reasoning. A complicated notebook with weak validation is worse than a simple notebook that answers the business question correctly.
#
# **Evidence before protected review:** Save runnable notebook cells, validation output, one error/recovery note, own-words explanation, and confidence 1-5.

# %%
# PY10 changed independent attempt
# Close learner/review material before coding here.

# %% [markdown]
# # M-PY — Integrated analyst workflow project
#
# **Business request:** Management wants a concise view of sales performance, return/refund impact, regional concentration and delivery behavior. Build an auditable notebook that another analyst can rerun.
#
# **Required route**
# 1. Preserve raw frames.
# 2. Audit source grain/keys/types/missing/invalid/duplicates.
# 3. Build a justified strict analysis set.
# 4. Calculate net sales at line grain.
# 5. Validate product merge with `validate=` and `indicator=True`.
# 6. Do **not** merge order-level `returns` directly to line rows and multiply refunds. First aggregate sales to order grain or aggregate returns appropriately.
# 7. Build region/month/category analyses plus purposeful visuals.
# 8. Reconcile important row counts/totals.
# 9. State findings, recommendation and limitations.
# 10. Save outputs and **Restart Kernel → Run All**.
#
# Protected review is closed until the project attempt is saved.

# %%
# M-PY integrated project attempt
# Build your end-to-end workflow here or add clearly named cells below this marker.

# %% [markdown]
# ## Final reproducibility check
#
# Before Gate A:
# - Restart Kernel.
# - Run All.
# - No hidden-state error.
# - Output paths are relative and recreateable.
# - Important totals/counts reconcile.
# - Findings distinguish evidence from hypothesis.
# - Save notebook + output files + one error/recovery note.
